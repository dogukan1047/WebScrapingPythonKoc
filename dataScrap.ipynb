# %%
import requests
from bs4 import BeautifulSoup

header={
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"
}

url = "https://happymoonsemaar.jacca.com/Menu?C=view_tr_happymoonsemaar_99"
parser=BeautifulSoup(requests.get(url,headers=header).content,"html.parser")

def catagory():
    catagory = parser.find_all("li", {"class": "menuCategory pCategory"})
    for i in catagory
# Out:
# [<li class="menuCategory pCategory" data-cbehaviourunit="6968" data-mbehaviourunit="30875" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6968"></span>
# <div style="display:none;">KAHVALTILAR KAHVALTILAR</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6969" data-mbehaviourunit="30876" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6969"></span>
# <div style="display:none;">BAŞLANGIÇLAR BAŞLANGIÇLAR</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6970" data-mbehaviourunit="30877" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6970"></span>
# <div style="display:none;">SALATALAR SALATALAR</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6971" data-mbehaviourunit="30878" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6971"></span>
# <div style="display:none;">BURGERLER BURGERLER</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6972" data-mbehaviourunit="30879" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6972"></span>
# <div style="display:none;">MEKSİKA YEMEKLERİ MEKSİKA YEMEKLERİ</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6973" data-mbehaviourunit="30880" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6973"></span>
# <div style="display:none;">MAKARNALAR MAKARNALAR</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6974" data-mbehaviourunit="30881" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6974"></span>
# <div style="display:none;">ANA YEMEKLER ANA YEMEKLER</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6975" data-mbehaviourunit="30882" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6975"></span>
# <div style="display:none;">PİZZALAR PİZZALAR</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6976" data-mbehaviourunit="30883" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6976"></span>
# <div style="display:none;">DÜRÜMLER VE KREPLER DÜRÜMLER VE KREPLER</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6977" data-mbehaviourunit="30884" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6977"></span>
# <div style="display:none;">ÇOCUKLARA ÖZEL ÇOCUKLARA ÖZEL</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6978" data-mbehaviourunit="30885" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6978"></span>
# <div style="display:none;">HAFİF LEZZETLER HAFİF LEZZETLER</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6979" data-mbehaviourunit="30886" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6979"></span>
# <div style="display:none;">TATLILAR TATLILAR</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6980" data-mbehaviourunit="30887" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6980"></span>
# <div style="display:none;">SICAK İÇECEKLER SICAK İÇECEKLER</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6981" data-mbehaviourunit="30887" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6981"></span>
# <div style="display:none;">SICAK İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:60px;">AROMALI KAHVELER</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6982" data-mbehaviourunit="30887" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6982"></span>
# <div style="display:none;">SICAK İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:60px;">SPECIAL KAHVELER</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6983" data-mbehaviourunit="30887" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6983"></span>
# <div style="display:none;">SICAK İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:60px;">BİTKİ VE MEYVE ÇAYLARI</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6984" data-mbehaviourunit="30888" data-mipoint="4840" style="height:0px;">
# <span class="anchor388" id="6984"></span>
# <div style="display:none;">İÇECEKLER İÇECEKLER</div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6985" data-mbehaviourunit="30888" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6985"></span>
# <div style="display:none;">İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:60px;">BUZLU KAHVELER</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6986" data-mbehaviourunit="30888" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6986"></span>
# <div style="display:none;">İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:60px;">MILKSHAKELER</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6987" data-mbehaviourunit="30888" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6987"></span>
# <div style="display:none;">İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:60px;">ALKOLSÜZ KOKTEYLLER</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6988" data-mbehaviourunit="30888" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6988"></span>
# <div style="display:none;">İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:60px;">BUBBLE TEA</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6989" data-mbehaviourunit="30888" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6989"></span>
# <div style="display:none;">İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:60px;">LİMONATA</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6990" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6990"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">ALKOLLÜ KOKTEYLLER</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6991" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6991"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">TRENDLER</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6992" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6992"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">BİRALAR</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6993" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6993"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">İTHAL BİRALAR</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6994" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6994"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">YANINDA İYİ GİDER</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="8659" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="8659"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">KADEH ŞARAPLAR</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6995" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6995"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">BEYAZ ŞARAPLAR</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6996" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6996"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">KIRMIZI ŞARAPLAR</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6997" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6997"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">ROSE ŞARAPLAR</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="6999" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="6999"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">BOURBON &amp; SCOTCH (Tek)</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="7000" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="7000"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">KONYAK</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="7001" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="7001"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">LİKÖRLER</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="7002" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="7002"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">TEKİLA &amp; ROM</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="7003" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="7003"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">VODKA &amp; CİN</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="7004" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="7004"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">VERMUT</div>
# </div>
# </div>
# </li>, <li class="menuCategory pCategory" data-cbehaviourunit="7005" data-mbehaviourunit="30889" data-mipoint="4840" style="color:#ffffff;background:#E30613;text-align:center;font-family:TekoBold;">
# <span class="anchor388" id="7005"></span>
# <div style="display:none;">ALKOLLÜ İÇECEKLER</div>
# <div class="aligner titleAligner">
# <div class="alignerItem fixed title">
# <div class="categoryName" style="font-size:40px;">YANINDA İYİ GİDER</div>
# </div>
# </div>
# </li>]

# %%
# Out:
# None
